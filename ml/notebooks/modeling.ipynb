# %% [markdown]
# # Modeling - PTLD Risk
#
# - Feature engineering pipeline
# - Train/val split (patient-level), 5-fold CV
# - Models: LR (baseline), RandomForest, XGBoost; optional stacking
# - Metrics: AUROC, AUPRC, sensitivity @ target specificity, calibration
# - SHAP global/local
# - Save artifacts to `../models/` with `model_version`

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# TODO: load engineered dataset
# df = pd.read_csv("../data/processed/features.csv")
