# %% [markdown]
# # EDA - PTLD Risk
#
# - Load raw (local, secure) + synthetic data
# - Data dictionary, missingness
# - Univariate/bivariate distributions
# - Temporal trends
# - Save profiling HTML (ydata-profiling)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

synthetic_path = "../data/synthetic/patients.csv"
patients = pd.read_csv(synthetic_path)
patients.head()
